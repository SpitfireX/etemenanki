# %%
import pandas as pd
data = [
    (1, 0.00042235517),
    (2, 0.009181456),
    (3, 0.023049615),
    (4, 0.039753336),
    (5, 0.05797654),
    (6, 0.074758925),
    (7, 0.091434464),
    (8, 0.10765918),
    (9, 0.12331861),
    (10, 0.13807757),
    (20, 0.25206855),
    (30, 0.32525605),
    (40, 0.37708452),
    (50, 0.4164249),
    (60, 0.4477144),
    (70, 0.47332016),
    (80, 0.49462342),
    (90, 0.5128343),
    (100, 0.5286481),
    (200, 0.62281775),
    (300, 0.6721338),
    (400, 0.7050446),
    (500, 0.7292577),
    (600, 0.7482088),
    (700, 0.7633449),
    (800, 0.776017),
    (900, 0.7868688),
    (1000, 0.7962651),
    (2000, 0.8530383),
    (3000, 0.8823637),
    (4000, 0.9018771),
    (5000, 0.9159528),
    (6000, 0.92668337),
    (7000, 0.9351105),
    (8000, 0.9418204),
    (9000, 0.9473453),
    (10000, 0.9518905)
]

pd.DataFrame(data, columns=['Cache Size','Hit Ratio']).set_index('Cache Size').plot(kind='line', logx=True, logy=False, title='InvertedIndex Cache Performance');
